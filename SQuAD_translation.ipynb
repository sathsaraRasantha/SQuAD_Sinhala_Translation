# %%
import googletrans
from googletrans import Translator

import os
from google.cloud import translate_v2 as translate

os.environ['GOOGLE_APPLICATION_CREDENTIALS']=r"C:\Users\Sathsara\Documents\Python Learning\Translation test\translationAPI\flash-medley-278816-b2012b874797.json"

# %%
# create a translator object
translator = Translator()

# use translate method to translate a string - by default, the destination language is english
translated = translator.translate('I am Sathsara Rasantha',dest='si')

# the translate method returns an object
print(translated)


# obtain translated string by using attribute .text
translated.text
# Out:
# Translated(src=gu, dest=si, text=ඊ ම්ම් sathasara rasanatha, pronunciation=ī mm sathasara rasanatha, extra_data="{'translat...")
# 'ඊ ම්ම් sathasara rasanatha'

# %%
import pandas as pd


translate_example = pd.read_json("example2.json")
translate_example
# Out:
#                                                 data  version
# 0  {'title': 'University_of_Notre_Dame', 'paragra...      1.1
# 1  {'title': 'Beyoncé', 'paragraphs': [{'context'...      1.1
# 2  {'title': 'Montana', 'paragraphs': [{'context'...      1.1

# %%
contexts = []
questions = []
answers_text = []
answers_start = []
for i in range(translate_example.shape[0]):
    topic = translate_example.iloc[i,0]['paragraphs']
    for sub_para in topic:
        for q_a in sub_para['qas']:
            questions.append(q_a['question'])
            answers_start.append(q_a['answers'][0]['answer_start'])
            answers_text.append(q_a['answers'][0]['text'])
            contexts.append(sub_para['context'])   
df = pd.DataFrame({"context":contexts, "question": questions, "answer_start": answers_start, "text": answers_text})

df
# Out:
#                                                 context  \
# 0     Architecturally, the school has a Catholic cha...
# 1     Architecturally, the school has a Catholic cha...
# 2     Architecturally, the school has a Catholic cha...
# 3     Architecturally, the school has a Catholic cha...
# 4     Architecturally, the school has a Catholic cha...
# ...                                                 ...
# 1172  When the U.S. entered World War II on December...
# 1173  When the U.S. entered World War II on December...
# 1174  When the U.S. entered World War II on December...
# 1175  When the U.S. entered World War II on December...
# 1176  When the U.S. entered World War II on December...
#
#                                                question  answer_start  \
# 0     To whom did the Virgin Mary allegedly appear i...           515
# 1     What is in front of the Notre Dame Main Building?           188
# 2     The Basilica of the Sacred heart at Notre Dame...           279
# ...

# %%
import pandas as pd
data=pd.read_csv("G:\\Uni\\Final Year Research\\QA Dataset.csv")
data.head()
data=data.loc[400:500,:]
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
# make a deep copy of the data frame
df_si = data.copy()

# translate columns' name using rename function
df_si.rename(columns=lambda x: translator.translate(x).text, inplace=True)


df_si.columns=['Unnamed', 'Text', 'Questions', 'Answers']
df_si.columns
df_si=df_si.drop(['Unnamed'], axis=1)
df_si
# Out:
#                                                   Text  \
# 400  Windows 8 introduced major changes to the oper...
# 401  At no more than 200 kilometres (120 mi) north ...
# 402  The English word "translation" derives from th...
# 403  An airport is an aerodrome with facilities for...
# 404  Kievan Rus' begins with the rule (882–912) of ...
# 405  The Super Nintendo Entertainment System (offic...
# 406  However, some scholars contest the idea of a P...
# 407  Tuvalu (i/tuːˈvɑːluː/ too-VAH-loo or /ˈtuːvəlu...
# 408  The defined dogma of the Immaculate Conception...
# 409  Namibia has free education for both Primary an...
# 410  Russian (ру́сский язы́к, russkiy yazyk, pronou...
# 411  The United States Air Force (USAF) is the aeri...
# 412  Recent developments in LEDs permit them to be ...
# 413  The term "great power" was first used to repre...
# 414  Birds (Aves) are a group of endothermic verteb...
# 415  The Qing dynasty (Chinese: 清朝; pinyin: Qīng Ch...
# ...

# %%
translations = {}
for column in df_si.columns:
    # unique elements of the column
    unique_elements = df_si[column].unique()
    for element in unique_elements:
        # add translation to the dictionary
        translations[element] = translator.translate(element,dest='si').text
    


# modify all the terms of the data frame by using the previously created dictionary
df_si.replace(translations, inplace = True)

# check translation
df_si
# Out:
#                                                   Text  \
# 400  වින්ඩෝස් 8 වින්ඩෝස් දැන් Android සහ iOS ඇතුළු ...
# 401  දකුණු උතුරු හා කිලෝ මීටර් 130 (81 සැත) නැගෙනහි...
# 402  ඉංග්රීසි වචනය (ම trans- හා fero සිට එන තේරුම "...
# 403  මත්තල ගුවන් තොටුපොළ ගලවන්න හා ඉඩම් ගුවන් ගමන් ...
# 404  Kievan RUS 'ඔහුගේ පාලනය නොව්ගොරොද් දකුණු සිට D...
# 405  සුපිරි නින්ටෙන්ඩෝ එන්ටර්ටේන්මන්ට් ([ඇ] සුපිරි ...
# 406  කෙසේ වෙතත්, සමහර උගතුන් යුගවල සිට-Euphratean භ...
# 407  කලින් වසරේ දී එලිස් දූපත් ලෙස හඳුන්වන ටුවාලු (...
# 408  මෙම නිර්මල පිළිසිදගැනීම ඇති අර්ථ ධර්ම පාඨයක් ප...
# 409  නැමීබියාව ප්රාථමික සහ ද්විතීයික අධ්යාපනය මට්ටම...
# 410  රුසියානු (русский язык, russkiy yazyk, විශද [r...
# 411  එක්සත් ජනපදයේ ගුවන් හමුදාව (USAF) එක්සත් ජනපදය...
# 412  LED මඟින් මෑත වර්ධනයන් පාරිසරික හා කාර්ය සාධක ...
# 413  "මහත් බලය" යන වචනය මුලින්ම පශ්චාත් නැපෝලියානු ...
# 414  පක්ෂීන් (Aves) පිහාටු මගින් සංලක්ෂිත තාප අවශෝෂ...
# 415  කුයීන් (චීන: 清朝; පින්යින්: Qīng Cháo; වේඩ්-Gil...
# ...

# %%
df_si.to_csv(r'C:\Users\Sathsara\Documents\Python Learning\Translation test\translationAPI\3.csv', index = False)

# %%
data=pd.read_csv("G:\\Uni\\Final Year Research\\QA Dataset.csv")
data.head()
data=data.loc[500:800,:]

# make a deep copy of the data frame
df_si1 = data.copy()

# translate columns' name using rename function
df_si1.rename(columns=lambda x: translator.translate(x).text, inplace=True)


df_si1.columns=['Unnamed', 'Text', 'Questions', 'Answers']
df_si1.columns
df_si1=df_si1.drop(['Unnamed'], axis=1)
df_si1


translations = {}
for column in df_si1.columns:
    # unique elements of the column
    unique_elements = df_si1[column].unique()
    for element in unique_elements:
        # add translation to the dictionary
        translations[element] = translator.translate(element,dest='si').text
    


# modify all the terms of the data frame by using the previously created dictionary
df_si1.replace(translations, inplace = True)

df_si1
# Out:
# Empty DataFrame
# Columns: [Text, Questions, Answers]
# Index: []

# %%
df_si.Text
# Out:
# 0    Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 1    Frédéric François Chopin (/ˈʃoʊpæn/; French pr...
# Name: Text, dtype: object

# %%
data
data.columns=['Unnamed', 'Text', 'Questions', 'Answers']
data
# Out:
#    Unnamed                                               Text  \
# 0        0  Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 1        1  Frédéric François Chopin (/ˈʃoʊpæn/; French pr...
#
#                                            Questions  \
# 0  ['When did Beyonce start becoming popular?', '...
# 1  ["What was Frédéric's nationalities?", 'In wha...
#
#                                              Answers
# 0  ['in the late 1990s', 'singing and dancing', '...
# 1  ['Polish and French', 'Romantic era', 'solo pi...

# %%
dataframe=data.copy()
x=range(2)
y=['Unnamed', 'Text', 'Questions', 'Answers']
for i in x:
    for j in y:
       print(type(data.loc[i,j]))
# Out:
# <class 'numpy.int64'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'numpy.int64'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
# Out:
#    Unnamed                                               Text  \
# 0        0  Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 1        1  Frédéric François Chopin (/ˈʃoʊpæn/; French pr...
#
#                                            Questions  \
# 0  ['When did Beyonce start becoming popular?', '...
# 1  ["What was Frédéric's nationalities?", 'In wha...
#
#                                              Answers
# 0  ['in the late 1990s', 'singing and dancing', '...
# 1  ['Polish and French', 'Romantic era', 'solo pi...

# %%
data1=pd.read_csv("C:\\Users\\Sathsara\\Documents\\Python Learning\\kc_house_data1.csv")
data1.loc[0,'bedrooms']=5
data1
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         5       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
view=pd.read_csv("C:\\Users\\Sathsara\\Documents\\Python Learning\\Translation test\\translationAPI\\first_try.csv")
view
# Out:
#                                                 Text  \
# 0  බියොන්සේ Giselle නෝව්ල්ස්-කාටර් (/ biːjɒnseɪ /...
# 1  ෆෙඩ්රික් ෆ්රන්සුවා චොපින් යනු (/ ʃoʊpæn /; ප්ර...
#
#                                            Questions  \
# 0  [ 'විට Beyonce ජනප්රිය වෙමින් ආරම්භ කළේ?', 'ඇය...
# 1  [ෆෙඩ්රික් පිටත්ව ගියා දේ වයස අවුරුදු "මොන ෆෙඩ්...
#
#                                              Answers
# 0  [ '1990 අග භාගයේ දී', 'ගායන සහ නර්තන', '2003',...
# 1  [ 'පෝලන්ත හා ප්රංශ', 'ප්රේමාන්විත යුගය', 'ඒකල ...

# %%
import pandas as pd
view2=pd.read_csv("C:\\Users\\Sathsara\\Documents\\Python Learning\\Translation test\\translationAPI\\2.csv")
view2
# Out:
#                                                  Text  \
# 0   ටිබෙට් හා චීනයේ මින්ග් රාජවංශය (1368-1644) අතර...
# 1   මෙම අයි-පොඩ් අතේ ගෙන යා හැකි මාධ්ය ක්රීඩකයන් හ...
# 2   බියොන්සේ Giselle නෝව්ල්ස්-කාටර් (/ biːjɒnseɪ /...
# 3   ෆෙඩ්රික් ෆ්රන්සුවා චොපින් යනු (/ ʃoʊpæn /; ප්ර...
# 4   ටිබෙට් හා චීනයේ මින්ග් රාජවංශය (1368-1644) අතර...
# ..                                                ...
# 94  1936 අගෝස්තු මස ආරම්භ වන රූපවාහිනී පද්ධති විස්...
# 95  එය ඉන්ධන යන දෙකම සඳහා සහ ඉදිකිරීම් ද්රව්ය ලෙස ...
# 96  සෝමාලියාවට (සෝමාලියානු: Soomaali, අරාබි: صومال...
# 97  යුරෝපීය ඉතිහාසයේ, මධ්යතන යුගයේ හෝ, මධ්යතන යුගය...
# 98  Phonology භාෂා ශබ්ද ක්රමානුකූලව සංවිධානය සමග අ...
#
#                                             Questions  \
# 0         [ 'වැන්ග් Jiawei හා Nyima Gyaincain? කවුද']
# 1   [ 'මේ අයි-පොඩ් නිෂ්පාදනය කුමන සමාගම?', 'මුල් අ...
# 2   [ 'විට Beyonce ජනප්රිය වෙමින් ආරම්භ කළේ?', 'ඇය...
# 3   [ෆෙඩ්රික් පිටත්ව ගියා දේ වයස අවුරුදු "මොන ෆෙඩ්...
# ...

# %%
view2.iloc[95,2]
# Out:
# "[[{ 'පෙළ' 'ඉන්ධන', 'answer_start': 49}], [{ 'පෙළ' 'සෙලියුලෝස්', 'answer_start': 136}], [{ 'පෙළ' 'වියෝජනයට', 'answer_start' : 207}], [{ 'පෙළ' 'සහයෝගය', 'answer_start': 482}], [{ 'පෙළ' 'පෝෂ්ය පදාර්ථ', 'answer_start': 592}]]"

# %%
contexts = []
questions = []
answers_text = []
answers_start = []
for i in range(view2.shape[0]):
    topic = view2.iloc[i,0]['paragraphs']
    for sub_para in topic:
        for q_a in sub_para['qas']:
            questions.append(q_a['question'])
            answers_start.append(q_a['answers'][0]['answer_start'])
            answers_text.append(q_a['answers'][0]['text'])
            contexts.append(sub_para['context'])   
df = pd.DataFrame({"context":contexts, "question": questions, "answer_start": answers_start, "text": answers_text})
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-e68fffd5209d> in <module>
#       4 answers_start = []
#       5 for i in range(view2.shape[0]):
# ----> 6     topic = view2.iloc[i,0]['paragraphs']
#       7     for sub_para in topic:
#       8         for q_a in sub_para['qas']:
#
# TypeError: string indices must be integers

# %%
view2.to_json(r'C:\Users\Sathsara\Documents\Python Learning\Translation test\translationAPI\view2.json')

# %%
view3= pd.read_json("view2.json")
view3
# Out:
#                                                  Text  \
# 0   ටිබෙට් හා චීනයේ මින්ග් රාජවංශය (1368-1644) අතර...
# 1   මෙම අයි-පොඩ් අතේ ගෙන යා හැකි මාධ්ය ක්රීඩකයන් හ...
# 2   බියොන්සේ Giselle නෝව්ල්ස්-කාටර් (/ biːjɒnseɪ /...
# 3   ෆෙඩ්රික් ෆ්රන්සුවා චොපින් යනු (/ ʃoʊpæn /; ප්ර...
# 4   ටිබෙට් හා චීනයේ මින්ග් රාජවංශය (1368-1644) අතර...
# ..                                                ...
# 94  1936 අගෝස්තු මස ආරම්භ වන රූපවාහිනී පද්ධති විස්...
# 95  එය ඉන්ධන යන දෙකම සඳහා සහ ඉදිකිරීම් ද්රව්ය ලෙස ...
# 96  සෝමාලියාවට (සෝමාලියානු: Soomaali, අරාබි: صومال...
# 97  යුරෝපීය ඉතිහාසයේ, මධ්යතන යුගයේ හෝ, මධ්යතන යුගය...
# 98  Phonology භාෂා ශබ්ද ක්රමානුකූලව සංවිධානය සමග අ...
#
#                                             Questions  \
# 0         [ 'වැන්ග් Jiawei හා Nyima Gyaincain? කවුද']
# 1   [ 'මේ අයි-පොඩ් නිෂ්පාදනය කුමන සමාගම?', 'මුල් අ...
# 2   [ 'විට Beyonce ජනප්රිය වෙමින් ආරම්භ කළේ?', 'ඇය...
# 3   [ෆෙඩ්රික් පිටත්ව ගියා දේ වයස අවුරුදු "මොන ෆෙඩ්...
# ...
